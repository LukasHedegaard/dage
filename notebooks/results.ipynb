# %% [markdown]
# # Test evaluations

# %%
from os.path import realpath
from pathlib import Path
import pandas as pd
import itertools
import json
import shutil
import matplotlib.pyplot as plt
import seaborn as sns

def load_json(path):
    with open(path) as f:
        cfg = json.load(f)
    return cfg

RUNS_DIR = Path(realpath('.')) / 'runs'
if not 'dage/runs' in str(RUNS_DIR):
    RUNS_DIR = Path(realpath('.')).parent / 'runs'
assert('dage/runs' in str(RUNS_DIR))

def load_cls_rep_paths_new(
    method,
    experiment_id,
    prefix=None,
    config_dict={},
):
    d = RUNS_DIR / method / experiment_id
    paths = []
    for item in d.glob('*'):
        if (item.is_dir()):
            if prefix:
                if not item.name.startswith(prefix):
                    continue
            if config_dict:
                config = load_json(item / 'config.json')
                if not all([config[k]==v for k,v in config_dict.items()]):
                    continue
            paths.append( item / 'report.json' ) 
    return sorted([p for p in paths if p.exists()])

def get_score_new(
    report_paths,
    metric:str='precision',
    avg_types=['macro avg', 'weighted avg'],
    map_col_name= lambda n: n
):
    reports = [ pd.read_json(p) for p in report_paths ]
    score = pd.DataFrame(
        [[r[avgt][metric] for avgt in avg_types]
         for r in reports
        ],
        columns = [ map_col_name(avgt) for avgt in avg_types]
    ) 
    return score


def get_score_combinations_new(
    method,
    experiment_id,
    config_key=None,
    config_value=None,
    config_dict={},
    domains=['A','W','D'], 
    metric:str='recall',
    avg_types=['macro avg'],
):
    if config_key and config_value:
        config_dict[config_key] = config_value
        
    combos = [c for c in itertools.product(domains, repeat=2) if c[0] != c[1]]
    scores = [
        get_score_new(
            report_paths=load_cls_rep_paths_new(method, experiment_id, '{}{}'.format(c[0],c[1]), config_dict),
            metric=metric,
            avg_types=avg_types,
            map_col_name=lambda n: '{}->{}'.format(c[0],c[1]),
        )
        for c in combos
    ]
    return pd.concat(scores, sort=False)


def present(df, name):
    df = df.describe().T[['mean','std']]
    tot_mean = df.mean()[['mean']]
    
    toStr = lambda s: f'{s:.2f}'
    df = df['mean'].map(toStr) + ' ±' + df['std'].map(toStr)
    df = pd.concat([df,tot_mean[['mean']]])
    return pd.DataFrame(df, columns=[name]).T


def highlight_max(s):
    is_max = s == s.max()
    return ['font-weight: bold' if v else '' for v in is_max]

# %% [markdown]
# ## Tune source only
# In this experiment, we tune a VGG16-network pretrained on ImageNet with all available source data.
# The target data is used for validation (during training) and test.

# %%
tune_source_no_aug_scores = get_score_combinations_new(
    method='tune_source',
    experiment_id='tune_source_no_aug',
)*100
tune_source_no_aug_scores.describe().T.sort_index()
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->D    5.0  62.255293  2.876099  58.703566  60.118168  62.317043  64.882089
# A->W    5.0  53.909982  1.816761  51.745806  52.443511  54.047886  55.303047
# D->A    5.0  37.601127  2.356256  34.128049  36.512041  38.335136  38.775862
# D->W    5.0  90.982524  2.225432  87.885781  89.989964  90.893983  92.571363
# W->A    5.0  42.579908  1.533883  40.575395  41.629445  42.976339  43.131344
# W->D    5.0  98.707230  0.655752  98.064412  98.263400  98.634153  98.822325
#
#             max
# A->D  65.255601
# A->W  56.009660
# D->A  40.254545
# D->W  93.571528
# W->A  44.587021
# W->D  99.751861

# %%
tune_source_scores = get_score_combinations_new(
    method='tune_source',
    experiment_id='tune_source_with_aug',
)*100
tune_source_scores.describe().T.sort_index()
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->D    5.0  65.859347  2.230132  63.796151  64.761948  65.003669  66.188868
# A->W    5.0  56.567206  2.084737  53.898678  54.758035  57.814545  57.853058
# D->A    5.0  41.696940  1.640651  39.190639  41.082026  42.081671  42.737236
# D->W    5.0  92.875348  1.169019  90.854845  92.890177  93.381241  93.585405
# W->A    5.0  41.163056  2.133029  38.413584  40.117469  40.801652  42.617711
# W->D    5.0  98.691223  0.818735  97.452336  98.443617  98.762161  99.201229
#
#             max
# A->D  69.546098
# A->W  58.511712
# D->A  43.393128
# D->W  93.665070
# W->A  43.864865
# W->D  99.596774

# %% [markdown]
# ### Gradual Unfreeze Fine-tuning

# %%
ft_src_grad_unf_0_vgg16 = get_score_combinations_new(
    method='tune_source',
    experiment_id='gradual_unfreeze_vgg16_0',
)*100
ft_src_grad_unf_0_vgg16.describe().T
# Out:
#       count       mean      std        min        25%        50%        75%  \
# A->D    5.0  65.889501  3.74535  60.472616  63.650057  67.380143  68.460982
#
#             max
# A->D  69.483704

# %%
ft_src_grad_unf_2_vgg16 = get_score_combinations_new(
    method='tune_source',
    experiment_id='gradual_unfreeze_vgg16_2',
)*100
ft_src_grad_unf_2_vgg16.describe().T
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->D    5.0  67.078229  2.801691  62.942111  65.876221  67.375394  69.438023
#
#             max
# A->D  69.759397

# %%
ft_src_grad_unf_3_vgg16 = get_score_combinations_new(
    method='tune_source',
    experiment_id='gradual_unfreeze_vgg16_3',
)*100
ft_src_grad_unf_3_vgg16.describe().T
# Out:
#       count       mean      std        min        25%        50%        75%  \
# A->D    5.0  67.732249  2.62079  64.545128  65.210037  69.486343  69.542442
#
#             max
# A->D  69.877297

# %%
ft_src_grad_unf_4_vgg16 = get_score_combinations_new(
    method='tune_source',
    experiment_id='gradual_unfreeze_vgg16_4',
)*100
ft_src_grad_unf_4_vgg16.describe().T
# Out:
#       count       mean       std        min       25%        50%        75%  \
# A->D    5.0  67.735473  2.193459  64.569827  66.44739  68.603821  69.090516
#
#            max
# A->D  69.96581

# %%
ft_src_grad_unf_6_vgg16 = get_score_combinations_new(
    method='tune_source',
    experiment_id='gradual_unfreeze_vgg16_6',
)*100
ft_src_grad_unf_6_vgg16.describe().T
# Out:
#       count       mean       std        min        25%       50%        75%  \
# A->D    5.0  67.954058  1.763461  65.899232  67.503943  67.67719  67.918712
#
#             max
# A->D  70.771212

# %%
ft_src_grad_unf_7_vgg16 = get_score_combinations_new(
    method='tune_source',
    experiment_id='gradual_unfreeze_vgg16_7',
)*100
ft_src_grad_unf_7_vgg16.describe().T
# Out:
#       count      mean       std        min        25%        50%        75%  \
# A->D    5.0  68.33378  2.303235  65.440109  66.380372  69.232904  69.844706
#
#             max
# A->D  70.770809

# %%
ft_src_grad_unf_8_vgg16 = get_score_combinations_new(
    method='tune_source',
    experiment_id='gradual_unfreeze_vgg16_8',
)*100
ft_src_grad_unf_8_vgg16.describe().T
# Out:
#       count       mean       std        min       25%        50%       75%  \
# A->D    5.0  68.730472  2.277957  65.965728  67.05596  68.693416  70.58883
#
#             max
# A->D  71.348427

# %%
ft_src_grad_unf_10_vgg16 = get_score_combinations_new(
    method='tune_source',
    experiment_id='gradual_unfreeze_vgg16_10',
)*100
ft_src_grad_unf_10_vgg16.describe().T
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->D    4.0  69.595584  2.435421  66.165178  69.075152  70.150045  70.670477
#
#             max
# A->D  71.917067

# %%
ft_src_grad_unf_11_vgg16 = get_score_combinations_new(
    method='tune_source',
    experiment_id='gradual_unfreeze_vgg16_11',
)*100
ft_src_grad_unf_11_vgg16.describe().T
# Out:
#       count       mean       std        min        25%       50%        75%  \
# A->D    4.0  69.571248  1.186921  68.231463  68.911341  69.50811  70.168017
#
#             max
# A->D  71.037308

# %%
ft_src_grad_unf_12_vgg16 = get_score_combinations_new(
    method='tune_source',
    experiment_id='gradual_unfreeze_vgg16_12',
)*100
ft_src_grad_unf_12_vgg16.describe().T
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->D    4.0  70.071983  0.610344  69.325293  69.700486  70.169348  70.540845
#
#             max
# A->D  70.623943

# %% [markdown]
# ### Coarse gradual unfreeze

# %%
tune_source_vgg16_aug_coarse_grad = get_score_combinations_new(
    method='tune_source',
    experiment_id='vgg16_aug_coarse_grad_ft',
)*100
tune_source_vgg16_aug_coarse_grad.describe().T.sort_index()
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->D    5.0  66.636605  2.966424  61.512586  66.844356  67.688503  68.164576
# A->W    5.0  59.793897  2.125821  57.034714  59.304191  59.575454  60.084539
# D->A    5.0  42.816493  5.218414  33.990533  42.159687  45.591694  45.722539
# D->W    5.0  92.333845  2.764590  88.024718  91.065796  94.105682  94.148213
# W->A    5.0  43.998664  0.658633  43.309881  43.468084  44.044374  44.205728
# W->D    5.0  98.540254  1.236710  97.172397  97.742034  98.109417  99.677419
#
#              max
# A->D   68.973006
# A->W   62.970588
# D->A   46.618014
# D->W   94.324815
# W->A   44.965251
# W->D  100.000000

# %%
tune_source_resnet101_aug_coarse_grad = get_score_combinations_new(
    method='tune_source',
    experiment_id='resnet101v2_aug_coarse_grad_ft',
)*100
tune_source_resnet101_aug_coarse_grad.describe().T
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->W    5.0  72.751316  1.454845  71.240210  71.955371  72.341727  73.189988
# A->D    5.0  74.969336  1.329631  73.364764  73.919061  75.074968  75.985552
# W->A    5.0  59.596429  1.113659  58.532945  58.585823  59.465619  60.274189
# W->D    5.0  97.773171  0.733757  96.847018  97.292184  97.735732  98.396254
# D->A    5.0  60.118268  0.897086  59.117722  59.499037  59.863154  60.978827
# D->W    5.0  93.719617  1.281476  92.249463  92.427076  94.390690  94.543016
#
#             max
# A->W  75.029284
# A->D  76.502338
# W->A  61.123567
# W->D  98.594667
# D->A  61.132598
# D->W  94.987839

# %% [markdown]
# ### Comparison

# %%
grad_unfreeze_source_results = pd.DataFrame({ 
    '0'  : ft_src_grad_unf_0_vgg16['A->D'],
    '2'  : ft_src_grad_unf_2_vgg16['A->D'],
    '3'  : ft_src_grad_unf_3_vgg16['A->D'],
    '4'  : ft_src_grad_unf_4_vgg16['A->D'],
    '6'  : ft_src_grad_unf_6_vgg16['A->D'],
    '7'  : ft_src_grad_unf_7_vgg16['A->D'],
    '8'  : ft_src_grad_unf_8_vgg16['A->D'],
    '10' : ft_src_grad_unf_10_vgg16['A->D'],
    '11' : ft_src_grad_unf_11_vgg16['A->D'],
    '12' : ft_src_grad_unf_12_vgg16['A->D'],
#     '12_coarse'  : tune_source_vgg16_aug_coarse_grad['A->D'].dropna(),
})

grad_unfreeze_source_results
# Out:
#            0          2          3          4          6          7  \
# 0  63.650057  62.942111  65.210037  66.447390  67.918712  65.440109
# 1  60.472616  65.876221  64.545128  64.569827  65.899232  66.380372
# 2  67.380143  67.375394  69.486343  68.603821  67.677190  69.844706
# 3  69.483704  69.759397  69.877297  69.090516  70.771212  70.770809
# 4  68.460982  69.438023  69.542442  69.965810  67.503943  69.232904
#
#            8         10         11         12
# 0  67.055960  66.165178  68.231463  69.325293
# 1  65.965728  70.045143  69.137966  70.623943
# 2  70.588830  70.254947  71.037308  69.825551
# 3  71.348427  71.917067  69.878254  70.513146
# 4  68.693416        NaN        NaN        NaN

# %%
grad_unfreeze_source_results.describe().T
# Out:
#     count       mean       std        min        25%        50%        75%  \
# 0     5.0  65.889501  3.745350  60.472616  63.650057  67.380143  68.460982
# 2     5.0  67.078229  2.801691  62.942111  65.876221  67.375394  69.438023
# 3     5.0  67.732249  2.620790  64.545128  65.210037  69.486343  69.542442
# 4     5.0  67.735473  2.193459  64.569827  66.447390  68.603821  69.090516
# 6     5.0  67.954058  1.763461  65.899232  67.503943  67.677190  67.918712
# 7     5.0  68.333780  2.303235  65.440109  66.380372  69.232904  69.844706
# 8     5.0  68.730472  2.277957  65.965728  67.055960  68.693416  70.588830
# 10    4.0  69.595584  2.435421  66.165178  69.075152  70.150045  70.670477
# 11    4.0  69.571248  1.186921  68.231463  68.911341  69.508110  70.168017
# 12    4.0  70.071983  0.610344  69.325293  69.700486  70.169348  70.540845
#
#           max
# 0   69.483704
# 2   69.759397
# 3   69.877297
# 4   69.965810
# 6   70.771212
# 7   70.770809
# 8   71.348427
# 10  71.917067
# 11  71.037308
# 12  70.623943

# %%
plt.figure(figsize=(10,4))
sns.set()
sns.set_style("whitegrid")
sns.set_palette("Spectral")
# ax = sns.violinplot(data=grad_unfreeze_source_results, width=1)
# ax = sns.boxplot(data=grad_unfreeze_source_results, width=0.5)
# ax = sns.swarmplot(data=grad_unfreeze_source_results, color="0.25")
ax = sns.swarmplot(data=grad_unfreeze_source_results, size=7)
plt.xlabel('Number of unfrozen convolutional layers')
plt.ylabel('Test accuracy (%)')
plt.ylim((60,74))
plt.savefig('gradual-unfreeze-AD.pdf')

# %% [markdown]
# ## Tune source and target

# %% [markdown]
# ### Coarse gradual unfreeze

# %%
tune_target_vgg16_aug_coarse_grad_ft = get_score_combinations_new(
    method='tune_target',
    experiment_id='vgg16_aug_coarse_grad_ft',
)*100
tune_target_vgg16_aug_coarse_grad_ft.describe().T.sort_index()
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->D    5.0  71.354832  2.047845  69.217956  69.598614  71.136240  72.852380
# A->W    5.0  73.989078  4.948449  70.062192  71.046410  71.095686  75.883947
# D->A    5.0  56.201621  3.611262  53.372360  53.476973  54.126970  58.724620
# D->W    5.0  95.869260  1.167603  95.146474  95.190651  95.300098  95.804594
# W->A    5.0  50.226811  2.631192  46.918136  48.885330  49.591069  52.335316
# W->D    5.0  99.108672  0.806583  97.709293  99.327620  99.354030  99.354030
#
#             max
# A->D  73.968967
# A->W  81.857153
# D->A  61.307181
# D->W  97.904483
# W->A  53.404202
# W->D  99.798387

# %%
tune_target_resnet101v2_aug_coarse_grad_ft = get_score_combinations_new(
    method='tune_target',
    experiment_id='resnet101v2_aug_coarse_grad_ft',
)*100
tune_target_resnet101v2_aug_coarse_grad_ft.describe().T.sort_index()
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->D    6.0  86.200014  1.825390  84.220063  85.121348  85.722943  86.918689
# A->W    5.0  86.637348  1.054278  84.906934  86.629824  86.729457  87.249601
# D->A    5.0  62.905532  1.268804  61.641015  61.780017  62.662449  64.067289
# D->W    5.0  94.625185  0.317125  94.348822  94.413338  94.498291  94.738139
# W->A    5.0  60.932032  0.721214  60.024654  60.404908  61.155426  61.224453
# W->D    5.0  98.268413  0.487107  97.440673  98.249685  98.422594  98.604908
#
#             max
# A->D  89.296046
# A->W  87.670926
# D->A  64.376890
# D->W  95.127337
# W->A  61.850721
# W->D  98.624207

# %% [markdown]
# ## CCSA

# %%
ccsa_tuned_vgg16 = get_score_combinations_new(
    method='ccsa',
    experiment_id='ccsa_vgg16_tuned',
)*100
ccsa_tuned_vgg16.describe().T
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->W    5.0  87.535622  1.485454  86.590828  86.759887  86.860938  87.317571
# A->D    5.0  84.840757  2.144342  82.449100  83.714239  84.155303  85.918205
# W->A    5.0  64.011722  1.595328  61.740131  63.152612  64.371540  65.001105
# W->D    5.0  98.594448  0.380161  98.042588  98.404127  98.720475  98.776798
# D->A    5.0  66.457656  1.877848  64.241496  64.998860  67.016956  67.040978
# D->W    5.0  97.191010  0.648243  96.216220  96.938034  97.279134  97.691885
#
#             max
# A->W  90.148886
# A->D  87.966936
# W->A  65.793222
# W->D  99.028251
# D->A  68.989991
# D->W  97.829776

# %% [markdown]
# ## d-SNE

# %%
dsne_tuned_vgg16 = get_score_combinations_new(
    method='dsne',
    experiment_id='dsne_vgg16_tuned',
)*100
dsne_tuned_vgg16.describe().T
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->W    5.0  88.708650  1.940367  86.354795  87.885453  88.011103  89.994425
# A->D    5.0  86.477079  2.513476  83.330158  84.163633  88.084763  88.336852
# W->A    5.0  63.936340  1.165632  62.540055  63.063393  63.893964  64.934677
# W->D    5.0  99.000907  0.495231  98.602151  98.759434  98.858472  98.924731
# D->A    5.0  65.942406  1.144120  64.980919  65.150586  65.363730  66.546855
# D->W    5.0  97.575566  0.710516  96.841490  97.091191  97.400872  97.922209
#
#             max
# A->W  91.297476
# A->D  88.469990
# W->A  65.249609
# W->D  99.859748
# D->A  67.669942
# D->W  98.622067

# %% [markdown]
# ## DAGE

# %%
dage_lda_tuned_vgg16 = get_score_combinations_new(
    method='dage',
    experiment_id='dage_lda_vgg16_tuned',
)*100
dage_lda_tuned_vgg16.describe().T
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->W    5.0  87.817379  2.312507  85.304558  86.117817  87.190956  90.026386
# A->D    5.0  85.915320  2.826513  82.418740  83.761378  86.578523  87.356686
# W->A    5.0  64.153106  1.228216  62.457654  63.885081  63.977881  64.601998
# W->D    5.0  99.487739  0.445585  98.924731  99.127289  99.680536  99.706138
# D->A    5.0  66.240828  1.426281  65.059623  65.065414  65.873481  66.732370
# D->W    5.0  97.921389  0.586013  97.172466  97.551199  97.879514  98.499196
#
#              max
# A->W   90.447180
# A->D   89.461275
# W->A   65.842916
# W->D  100.000000
# D->A   68.473251
# D->W   98.504572

# %%
dage_mfa_tuned_vgg16 = get_score_combinations_new(
    method='dage',
    experiment_id='dage_mfa_vgg16_tuned',
)*100
dage_mfa_tuned_vgg16.describe().T
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->W    5.0  88.108995  1.975165  85.598601  87.056135  87.992410  89.109180
# A->D    5.0  83.568688  3.431887  79.554681  81.165066  83.338754  85.652749
# W->A    5.0  63.742269  1.688643  61.024040  63.574045  64.073486  64.465509
# W->D    6.0  99.511899  0.380837  98.861284  99.440660  99.520804  99.696120
# D->A    5.0  65.877713  1.650009  63.854054  65.196817  65.446891  66.661057
# D->W    5.0  96.630978  1.394311  94.886371  95.747716  96.691853  97.342561
#
#              max
# A->W   90.788650
# A->D   88.132190
# W->A   65.574265
# W->D  100.000000
# D->A   68.229747
# D->W   98.486390

# %% [markdown]
# ## Summary

# %% [markdown]
# ### Final results

# %%
df_vgg16_tuned = pd.concat([
    present(tune_source_vgg16_aug_coarse_grad, 'FT-Source (VGG16)'),
    present(tune_target_vgg16_aug_coarse_grad_ft, 'FT-Target (VGG16)'),
    present(ccsa_tuned_vgg16, 'CCSA (VGG16)'),
    present(dsne_tuned_vgg16, 'd-SNE (VGG16)'),
    present(dage_lda_tuned_vgg16, 'DAGE-LDA (VGG16)'),
    present(dage_mfa_tuned_vgg16, 'DAGE-MFA (VGG16)'),
])
df_vgg16_tuned.style.apply(highlight_max)
# Out:
# <style  type="text/css" >
# #T_bc0fc_row2_col4,#T_bc0fc_row3_col0,#T_bc0fc_row3_col1,#T_bc0fc_row3_col6,#T_bc0fc_row4_col2,#T_bc0fc_row4_col5,#T_bc0fc_row5_col3{
#             font-weight:  bold;
#         }</style><table id="T_bc0fc_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A->W</th>        <th class="col_heading level0 col1" >A->D</th>        <th class="col_heading level0 col2" >W->A</th>        <th class="col_heading level0 col3" >W->D</th>        <th class="col_heading level0 col4" >D->A</th>        <th class="col_heading level0 col5" >D->W</th>        <th class="col_heading level0 col6" >mean</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bc0fc_level0_row0" class="row_heading level0 row0" >FT-Source (VGG16)</th>
#                         <td id="T_bc0fc_row0_col0" class="data row0 col0" >59.79 ±2.13</td>
#                         <td id="T_bc0fc_row0_col1" class="data row0 col1" >66.64 ±2.97</td>
#                         <td id="T_bc0fc_row0_col2" class="data row0 col2" >44.00 ±0.66</td>
#                         <td id="T_bc0fc_row0_col3" class="data row0 col3" >98.54 ±1.24</td>
#                         <td id="T_bc0fc_row0_col4" class="data row0 col4" >42.82 ±5.22</td>
#                         <td id="T_bc0fc_row0_col5" class="data row0 col5" >92.33 ±2.76</td>
#                         <td id="T_bc0fc_row0_col6" class="data row0 col6" >67.353293</td>
#             </tr>
#             <tr>
#                         <th id="T_bc0fc_level0_row1" class="row_heading level0 row1" >FT-Target (VGG16)</th>
#                         <td id="T_bc0fc_row1_col0" class="data row1 col0" >73.99 ±4.95</td>
#                         <td id="T_bc0fc_row1_col1" class="data row1 col1" >71.35 ±2.05</td>
#                         <td id="T_bc0fc_row1_col2" class="data row1 col2" >50.23 ±2.63</td>
#                         <td id="T_bc0fc_row1_col3" class="data row1 col3" >99.11 ±0.81</td>
#                         <td id="T_bc0fc_row1_col4" class="data row1 col4" >56.20 ±3.61</td>
#                         <td id="T_bc0fc_row1_col5" class="data row1 col5" >95.87 ±1.17</td>
#                         <td id="T_bc0fc_row1_col6" class="data row1 col6" >74.458379</td>
#             </tr>
#             <tr>
#                         <th id="T_bc0fc_level0_row2" class="row_heading level0 row2" >CCSA (VGG16)</th>
#                         <td id="T_bc0fc_row2_col0" class="data row2 col0" >87.54 ±1.49</td>
#                         <td id="T_bc0fc_row2_col1" class="data row2 col1" >84.84 ±2.14</td>
#                         <td id="T_bc0fc_row2_col2" class="data row2 col2" >64.01 ±1.60</td>
#                         <td id="T_bc0fc_row2_col3" class="data row2 col3" >98.59 ±0.38</td>
#                         <td id="T_bc0fc_row2_col4" class="data row2 col4" >66.46 ±1.88</td>
#                         <td id="T_bc0fc_row2_col5" class="data row2 col5" >97.19 ±0.65</td>
#                         <td id="T_bc0fc_row2_col6" class="data row2 col6" >83.105202</td>
#             </tr>
#             <tr>
#                         <th id="T_bc0fc_level0_row3" class="row_heading level0 row3" >d-SNE (VGG16)</th>
#                         <td id="T_bc0fc_row3_col0" class="data row3 col0" >88.71 ±1.94</td>
#                         <td id="T_bc0fc_row3_col1" class="data row3 col1" >86.48 ±2.51</td>
#                         <td id="T_bc0fc_row3_col2" class="data row3 col2" >63.94 ±1.17</td>
#                         <td id="T_bc0fc_row3_col3" class="data row3 col3" >99.00 ±0.50</td>
#                         <td id="T_bc0fc_row3_col4" class="data row3 col4" >65.94 ±1.14</td>
#                         <td id="T_bc0fc_row3_col5" class="data row3 col5" >97.58 ±0.71</td>
#                         <td id="T_bc0fc_row3_col6" class="data row3 col6" >83.606825</td>
#             </tr>
#             <tr>
#                         <th id="T_bc0fc_level0_row4" class="row_heading level0 row4" >DAGE-LDA (VGG16)</th>
#                         <td id="T_bc0fc_row4_col0" class="data row4 col0" >87.82 ±2.31</td>
#                         <td id="T_bc0fc_row4_col1" class="data row4 col1" >85.92 ±2.83</td>
#                         <td id="T_bc0fc_row4_col2" class="data row4 col2" >64.15 ±1.23</td>
#                         <td id="T_bc0fc_row4_col3" class="data row4 col3" >99.49 ±0.45</td>
#                         <td id="T_bc0fc_row4_col4" class="data row4 col4" >66.24 ±1.43</td>
#                         <td id="T_bc0fc_row4_col5" class="data row4 col5" >97.92 ±0.59</td>
#                         <td id="T_bc0fc_row4_col6" class="data row4 col6" >83.589294</td>
#             </tr>
#             <tr>
#                         <th id="T_bc0fc_level0_row5" class="row_heading level0 row5" >DAGE-MFA (VGG16)</th>
#                         <td id="T_bc0fc_row5_col0" class="data row5 col0" >88.11 ±1.98</td>
#                         <td id="T_bc0fc_row5_col1" class="data row5 col1" >83.57 ±3.43</td>
#                         <td id="T_bc0fc_row5_col2" class="data row5 col2" >63.74 ±1.69</td>
#                         <td id="T_bc0fc_row5_col3" class="data row5 col3" >99.51 ±0.38</td>
#                         <td id="T_bc0fc_row5_col4" class="data row5 col4" >65.88 ±1.65</td>
#                         <td id="T_bc0fc_row5_col5" class="data row5 col5" >96.63 ±1.39</td>
#                         <td id="T_bc0fc_row5_col6" class="data row5 col6" >82.906757</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Digits

# %%
ccsa_mu = pd.concat([
    get_score_new(
        report_paths=load_cls_rep_paths_new(
            method='ccsa', 
            experiment_id='ccsa_mnist_usps', 
            config_dict={
                'num_target_samples_per_class':num_tgt
            }
        ),
        metric='recall',
        avg_types=['weighted avg'],
        map_col_name=lambda n: '{}'.format(num_tgt)
    )*100
    for num_tgt in [1,3,5,7]
], sort=False)
ccsa_mu.describe().T
# Out:
#    count       mean       std        min        25%        50%        75%  \
# 1   10.0  75.628753  2.082629  72.620564  74.397179  75.141037  76.055505
# 3   10.0  85.004558  1.383563  82.725615  83.769371  85.610757  86.057429
# 5   10.0  87.780822  0.743007  86.694064  87.207763  87.835616  88.123288
# 7   10.0  89.048490  0.701089  87.676121  88.723696  88.998170  89.366423
#
#          max
# 1  79.335760
# 3  86.608933
# 5  88.977169
# 7  90.247027

# %%
dsne_mu = pd.concat([
    get_score_new(
        report_paths=load_cls_rep_paths_new(
            method='dsne', 
            experiment_id='dsne_mnist_usps_v2', 
            config_dict={
                'num_target_samples_per_class':num_tgt
            }
        ),
        metric='recall',
        avg_types=['weighted avg'],
        map_col_name=lambda n: '{}'.format(num_tgt)
    )*100
    for num_tgt in [1,3,5,7]
], sort=False)
dsne_mu.describe().T
# Out:
#    count       mean        std        min        25%        50%        75%  \
# 1   10.0  68.972702   1.691020  65.386715  68.275705  68.917197  70.050045
# 3   11.0  74.033314  21.296058  10.000000  79.024613  80.173200  80.847767
# 5   10.0  86.113242   0.849170  84.858447  85.289954  86.447489  86.700913
# 7   10.0  87.674291   0.944690  86.120769  87.124886  87.900274  88.355444
#
#          max
# 1  71.692448
# 3  83.637192
# 5  87.159817
# 7  88.819762

# %%
dage_lda_mu = pd.concat([
    get_score_new(
        report_paths=load_cls_rep_paths_new(
            method='dage', 
            experiment_id='dage_lda_mnist_usps_v2', 
            config_dict={
                'num_target_samples_per_class':num_tgt
            }
        ),
        metric='recall',
        avg_types=['weighted avg'],
        map_col_name=lambda n: '{}'.format(num_tgt)
    )*100
    for num_tgt in [1,3,5,7]
], sort=False)
dage_lda_mu.describe().T
# Out:
#    count       mean       std        min        25%        50%        75%  \
# 1   10.0  67.002730  1.854335  64.667880  65.864422  66.574158  68.139217
# 3   10.0  82.742024  1.682923  80.045579  81.488149  82.611668  84.127165
# 5   10.0  89.031050  0.745391  87.579909  88.757991  89.118721  89.374429
# 7   10.0  90.656908  0.467667  89.926807  90.409424  90.722781  90.953797
#
#          max
# 1  70.846224
# 3  85.287147
# 5  90.210046
# 7  91.326624

# %% [markdown]
# ## Summary

# %%
df_vgg16_tuned = pd.concat([
    present(ccsa_mu, 'CCSA'),
    present(dsne_mu, 'd-SNE'),
    present(dage_lda_mu, 'DAGE-LDA'),

])
df_vgg16_tuned.style.apply(highlight_max)
# Out:
# <style  type="text/css" >
# #T_45150_row0_col0,#T_45150_row0_col1,#T_45150_row0_col4,#T_45150_row2_col2,#T_45150_row2_col3{
#             font-weight:  bold;
#         }</style><table id="T_45150_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >3</th>        <th class="col_heading level0 col2" >5</th>        <th class="col_heading level0 col3" >7</th>        <th class="col_heading level0 col4" >mean</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_45150_level0_row0" class="row_heading level0 row0" >CCSA</th>
#                         <td id="T_45150_row0_col0" class="data row0 col0" >75.63 ±2.08</td>
#                         <td id="T_45150_row0_col1" class="data row0 col1" >85.00 ±1.38</td>
#                         <td id="T_45150_row0_col2" class="data row0 col2" >87.78 ±0.74</td>
#                         <td id="T_45150_row0_col3" class="data row0 col3" >89.05 ±0.70</td>
#                         <td id="T_45150_row0_col4" class="data row0 col4" >84.365656</td>
#             </tr>
#             <tr>
#                         <th id="T_45150_level0_row1" class="row_heading level0 row1" >d-SNE</th>
#                         <td id="T_45150_row1_col0" class="data row1 col0" >68.97 ±1.69</td>
#                         <td id="T_45150_row1_col1" class="data row1 col1" >74.03 ±21.30</td>
#                         <td id="T_45150_row1_col2" class="data row1 col2" >86.11 ±0.85</td>
#                         <td id="T_45150_row1_col3" class="data row1 col3" >87.67 ±0.94</td>
#                         <td id="T_45150_row1_col4" class="data row1 col4" >79.198387</td>
#             </tr>
#             <tr>
#                         <th id="T_45150_level0_row2" class="row_heading level0 row2" >DAGE-LDA</th>
#                         <td id="T_45150_row2_col0" class="data row2 col0" >67.00 ±1.85</td>
#                         <td id="T_45150_row2_col1" class="data row2 col1" >82.74 ±1.68</td>
#                         <td id="T_45150_row2_col2" class="data row2 col2" >89.03 ±0.75</td>
#                         <td id="T_45150_row2_col3" class="data row2 col3" >90.66 ±0.47</td>
#                         <td id="T_45150_row2_col4" class="data row2 col4" >82.358178</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Runs V2
# In these experiments, we have updates the splits, such that an independent training split was set aside and not used during any other step than the final test

# %% [markdown]
# ## Office

# %%
ccsa_tuned_vgg16_v2 = get_score_combinations_new(
    method='ccsa',
    experiment_id='ccsa_vgg16_tuned_v2',
)*100
ccsa_tuned_vgg16_v2.describe().T
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->W    5.0  84.525464  2.061518  81.496962  83.910265  84.334671  86.267979
# A->D    5.0  86.355607  2.477475  82.442396  85.721966  86.824117  88.006912
# W->A    5.0  60.753285  1.445514  58.754148  60.135008  60.955995  61.245537
# W->D    5.0  98.417819  0.918212  96.850998  98.463902  98.655914  98.924731
# D->A    5.0  65.533460  1.199817  63.586146  65.488821  65.568676  66.355994
# D->W    5.0  97.448122  0.864335  96.077363  97.434716  97.556207  97.709817
#
#             max
# A->W  86.617442
# A->D  88.782642
# W->A  62.675736
# W->D  99.193548
# D->A  66.667664
# D->W  98.462505

# %%
dsne_tuned_vgg16_v2 = get_score_combinations_new(
    method='dsne',
    experiment_id='dsne_vgg16_tuned_v2',
)*100
dsne_tuned_vgg16_v2.describe().T
# Out:
#       count       mean       std        min        25%         50%  \
# A->W    5.0  82.248576  2.367535  79.242934  80.472672   82.526542
# A->D    5.0  84.645929  1.306405  83.060676  83.782642   84.673579
# W->A    5.0  59.895811  1.640471  57.404667  59.669705   59.711829
# W->D    5.0  99.677419  0.441712  99.193548  99.193548  100.000000
# D->A    5.0  65.128929  0.916822  64.385530  64.473409   64.737855
# D->W    5.0  98.191733  0.432126  97.709817  97.895545   98.079877
#
#              75%         max
# A->W   84.414349   84.586381
# A->D   85.291859   86.420891
# W->A   60.982261   61.710592
# W->D  100.000000  100.000000
# D->A   65.464941   66.582909
# D->W   98.540707   98.732719

# %%
dage_lda_tuned_vgg16_v2 = get_score_combinations_new(
    method='dage',
    experiment_id='dage_lda_vgg16_tuned_v2',
)*100
dage_lda_tuned_vgg16_v2.describe().T
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->W    5.0  84.268688  1.716646  82.178010  83.041940  84.152281  85.950286
# A->D    5.0  85.375576  2.634884  81.954685  83.786482  85.933180  86.313364
# W->A    5.0  65.454369  1.230775  63.416298  65.171601  66.086400  66.294265
# W->D    5.0  98.688172  0.515120  98.010753  98.387097  98.655914  99.193548
# D->A    5.0  64.876560  1.237723  63.286385  64.225389  65.005292  65.252054
# D->W    5.0  97.947493  0.339731  97.465438  97.849462  97.895545  98.170647
#
#             max
# A->W  86.020924
# A->D  88.890169
# W->A  66.303279
# W->D  99.193548
# D->A  66.613680
# D->W  98.356375

# %%
df_vgg16_tuned_v2 = pd.concat([
    present(ccsa_tuned_vgg16_v2, 'CCSA (VGG16)'),
    present(dsne_tuned_vgg16_v2, 'd-SNE (VGG16)'),
    present(dage_lda_tuned_vgg16_v2, 'DAGE-LDA (VGG16)'),
])
df_vgg16_tuned_v2.style.apply(highlight_max)
# Out:
# <style  type="text/css" >
# #T_6858e_row0_col0,#T_6858e_row0_col1,#T_6858e_row0_col4,#T_6858e_row1_col3,#T_6858e_row1_col5,#T_6858e_row2_col2,#T_6858e_row2_col6{
#             font-weight:  bold;
#         }</style><table id="T_6858e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A->W</th>        <th class="col_heading level0 col1" >A->D</th>        <th class="col_heading level0 col2" >W->A</th>        <th class="col_heading level0 col3" >W->D</th>        <th class="col_heading level0 col4" >D->A</th>        <th class="col_heading level0 col5" >D->W</th>        <th class="col_heading level0 col6" >mean</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6858e_level0_row0" class="row_heading level0 row0" >CCSA (VGG16)</th>
#                         <td id="T_6858e_row0_col0" class="data row0 col0" >84.53 ±2.06</td>
#                         <td id="T_6858e_row0_col1" class="data row0 col1" >86.36 ±2.48</td>
#                         <td id="T_6858e_row0_col2" class="data row0 col2" >60.75 ±1.45</td>
#                         <td id="T_6858e_row0_col3" class="data row0 col3" >98.42 ±0.92</td>
#                         <td id="T_6858e_row0_col4" class="data row0 col4" >65.53 ±1.20</td>
#                         <td id="T_6858e_row0_col5" class="data row0 col5" >97.45 ±0.86</td>
#                         <td id="T_6858e_row0_col6" class="data row0 col6" >82.172293</td>
#             </tr>
#             <tr>
#                         <th id="T_6858e_level0_row1" class="row_heading level0 row1" >d-SNE (VGG16)</th>
#                         <td id="T_6858e_row1_col0" class="data row1 col0" >82.25 ±2.37</td>
#                         <td id="T_6858e_row1_col1" class="data row1 col1" >84.65 ±1.31</td>
#                         <td id="T_6858e_row1_col2" class="data row1 col2" >59.90 ±1.64</td>
#                         <td id="T_6858e_row1_col3" class="data row1 col3" >99.68 ±0.44</td>
#                         <td id="T_6858e_row1_col4" class="data row1 col4" >65.13 ±0.92</td>
#                         <td id="T_6858e_row1_col5" class="data row1 col5" >98.19 ±0.43</td>
#                         <td id="T_6858e_row1_col6" class="data row1 col6" >81.631400</td>
#             </tr>
#             <tr>
#                         <th id="T_6858e_level0_row2" class="row_heading level0 row2" >DAGE-LDA (VGG16)</th>
#                         <td id="T_6858e_row2_col0" class="data row2 col0" >84.27 ±1.72</td>
#                         <td id="T_6858e_row2_col1" class="data row2 col1" >85.38 ±2.63</td>
#                         <td id="T_6858e_row2_col2" class="data row2 col2" >65.45 ±1.23</td>
#                         <td id="T_6858e_row2_col3" class="data row2 col3" >98.69 ±0.52</td>
#                         <td id="T_6858e_row2_col4" class="data row2 col4" >64.88 ±1.24</td>
#                         <td id="T_6858e_row2_col5" class="data row2 col5" >97.95 ±0.34</td>
#                         <td id="T_6858e_row2_col6" class="data row2 col6" >82.768476</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Digits

# %%
ccsa_mu = pd.concat([
    get_score_new(
        report_paths=load_cls_rep_paths_new(
            method='ccsa', 
            experiment_id='ccsa_mnist_usps_new', 
            config_dict={
                'num_target_samples_per_class':num_tgt
            }
        ),
        metric='recall',
        avg_types=['weighted avg'],
        map_col_name=lambda n: '{}'.format(num_tgt)
    )*100
    for num_tgt in [1,3,5,7]
], sort=False)
ccsa_mu.describe().T
# Out:
#    count       mean       std        min        25%        50%        75%  \
# 1   10.0  89.111233  1.047770  87.587437  88.242354  89.425319  89.946509
# 3   10.0  91.165821  0.847864  89.178439  91.074613  91.434645  91.691812
# 5   10.0  93.749829  0.395725  93.073652  93.457688  93.773145  94.044027
# 7   10.0  94.260047  0.368438  93.553696  94.194898  94.301193  94.551502
#
#          max
# 1  90.412838
# 3  91.894116
# 5  94.404060
# 7  94.623508

# %%
dsne_mu = pd.concat([
    get_score_new(
        report_paths=load_cls_rep_paths_new(
            method='dsne', 
            experiment_id='dsne_mnist_usps_new', 
            config_dict={
                'num_target_samples_per_class':num_tgt
            }
        ),
        metric='recall',
        avg_types=['weighted avg'],
        map_col_name=lambda n: '{}'.format(num_tgt)
    )*100
    for num_tgt in [1,3,5,7]
], sort=False)
dsne_mu.describe().T
# Out:
#    count       mean       std        min        25%        50%        75%  \
# 1   10.0  88.332190  1.711582  84.871760  87.412563  88.657249  89.459608
# 3   10.0  91.423673  1.213462  89.466466  90.635715  91.558085  92.326156
# 5   10.0  93.070909  0.485340  92.442738  92.751337  92.991359  93.385681
# 7   10.0  93.611302  0.621159  92.250720  93.522836  93.800576  93.913729
#
#          max
# 1  90.591140
# 3  93.142230
# 5  93.786861
# 7  94.376629

# %%
dage_lda_mu = pd.concat([
    get_score_new(
        report_paths=load_cls_rep_paths_new(
            method='dage', 
            experiment_id='dage_lda_mnist_usps_new', 
            config_dict={
                'num_target_samples_per_class':num_tgt
            }
        ),
        metric='recall',
        avg_types=['weighted avg'],
        map_col_name=lambda n: '{}'.format(num_tgt)
    )*100
    for num_tgt in [1,3,5,7]
], sort=False)
dage_lda_mu.describe().T
# Out:
#    count       mean       std        min        25%        50%        75%  \
# 1   10.0  88.750514  1.793957  85.818132  87.395419  89.013853  89.922507
# 3   10.0  92.433137  0.528599  91.592374  91.966123  92.538746  92.826773
# 5   10.0  93.357564  0.410960  92.799342  93.066795  93.389110  93.498834
# 7   10.0  94.048827  0.296392  93.635990  93.838294  94.074887  94.164038
#
#          max
# 1  91.386641
# 3  93.087368
# 5  94.212042
# 7  94.664655

# %%
df_vgg16_tuned = pd.concat([
    present(ccsa_mu, 'CCSA'),
    present(dsne_mu, 'd-SNE'),
    present(dage_lda_mu, 'DAGE-LDA'),

])
df_vgg16_tuned.style.apply(highlight_max)
# Out:
# <style  type="text/css" >
# #T_cfc0e_row0_col0,#T_cfc0e_row0_col2,#T_cfc0e_row0_col3,#T_cfc0e_row2_col1,#T_cfc0e_row2_col4{
#             font-weight:  bold;
#         }</style><table id="T_cfc0e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >3</th>        <th class="col_heading level0 col2" >5</th>        <th class="col_heading level0 col3" >7</th>        <th class="col_heading level0 col4" >mean</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cfc0e_level0_row0" class="row_heading level0 row0" >CCSA</th>
#                         <td id="T_cfc0e_row0_col0" class="data row0 col0" >89.11 ±1.05</td>
#                         <td id="T_cfc0e_row0_col1" class="data row0 col1" >91.17 ±0.85</td>
#                         <td id="T_cfc0e_row0_col2" class="data row0 col2" >93.75 ±0.40</td>
#                         <td id="T_cfc0e_row0_col3" class="data row0 col3" >94.26 ±0.37</td>
#                         <td id="T_cfc0e_row0_col4" class="data row0 col4" >92.071732</td>
#             </tr>
#             <tr>
#                         <th id="T_cfc0e_level0_row1" class="row_heading level0 row1" >d-SNE</th>
#                         <td id="T_cfc0e_row1_col0" class="data row1 col0" >88.33 ±1.71</td>
#                         <td id="T_cfc0e_row1_col1" class="data row1 col1" >91.42 ±1.21</td>
#                         <td id="T_cfc0e_row1_col2" class="data row1 col2" >93.07 ±0.49</td>
#                         <td id="T_cfc0e_row1_col3" class="data row1 col3" >93.61 ±0.62</td>
#                         <td id="T_cfc0e_row1_col4" class="data row1 col4" >91.609519</td>
#             </tr>
#             <tr>
#                         <th id="T_cfc0e_level0_row2" class="row_heading level0 row2" >DAGE-LDA</th>
#                         <td id="T_cfc0e_row2_col0" class="data row2 col0" >88.75 ±1.79</td>
#                         <td id="T_cfc0e_row2_col1" class="data row2 col1" >92.43 ±0.53</td>
#                         <td id="T_cfc0e_row2_col2" class="data row2 col2" >93.36 ±0.41</td>
#                         <td id="T_cfc0e_row2_col3" class="data row2 col3" >94.05 ±0.30</td>
#                         <td id="T_cfc0e_row2_col4" class="data row2 col4" >92.147511</td>
#             </tr>
#     </tbody></table>

# %%
sum([92.90, 93.55, 95.13, 96.13])/4
# Out:
# 94.4275

# %% [markdown]
# ## Runs V3 - ResNet50

# %% [markdown]
# ### Tune source

# %%
tune_source_resnet50v2 = get_score_combinations_new(
    method='tune_source',
    experiment_id='resnet50v2_aug',
)*100
tune_source_resnet50v2.describe().T.sort_index()
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->D    5.0  76.718126  1.421904  75.552995  76.033026  76.386329  76.436252
# A->W    5.0  69.809740  3.167756  64.861939  69.524723  69.580742  71.989032
# D->A    5.0  54.070466  1.094059  52.831044  53.169291  54.280643  54.519854
# D->W    5.0  94.409837  0.685758  93.312736  94.287075  94.483894  94.968079
# W->A    5.0  55.696521  0.813091  54.702488  55.038219  55.790999  56.457911
# W->D    5.0  96.282642  1.887394  94.055300  94.861751  96.129032  98.087558
#
#             max
# A->D  79.182028
# A->W  73.092266
# D->A  55.551498
# D->W  94.997404
# W->A  56.492988
# W->D  98.279570

# %%
tune_source_resnet50v2_cg = get_score_combinations_new(
    method='tune_source',
    experiment_id='resnet50v2_aug_coarse_grad_ft',
)*100
tune_source_resnet50v2_cg.describe().T.sort_index()
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->D    5.0  74.721198  2.482369  71.228879  73.966974  74.343318  76.309524
# A->W    5.0  70.190689  1.648759  67.930591  69.600489  70.207543  70.769929
# D->A    5.0  54.465714  1.119994  53.394782  53.483555  54.224236  55.284990
# D->W    5.0  95.777894  0.808048  94.819276  95.312107  95.538798  96.477215
# W->A    5.0  56.687033  1.884886  54.369855  55.498354  56.451371  58.125421
# W->D    5.0  98.150538  1.996717  94.784946  98.387097  98.387097  99.193548
#
#              max
# A->D   77.757296
# A->W   72.444894
# D->A   55.941007
# D->W   96.742075
# W->A   58.990164
# W->D  100.000000

# %%
tune_source_resnet50 = get_score_combinations_new(
    method='tune_source',
    experiment_id='resnet50_aug',
)*100
tune_source_resnet50.describe().T.sort_index()
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->D    5.0  75.373272  2.518170  72.596006  73.966974  74.930876  76.140553
# A->W    5.0  67.788437  2.083621  64.969305  67.162005  67.666903  68.421095
# D->A    5.0  50.692328  1.620379  49.208295  49.281285  50.632003  51.185580
# D->W    5.0  96.465640  0.482218  95.660290  96.461818  96.605223  96.662826
# W->A    5.0  51.393549  0.939709  50.260510  50.581609  51.806174  51.809813
# W->D    5.0  98.924731  0.931210  97.311828  99.193548  99.193548  99.193548
#
#             max
# A->D  79.231951
# A->W  70.722879
# D->A  53.154478
# D->W  96.938044
# W->A  52.509637
# W->D  99.731183

# %%
tune_source_resnet50_cg = get_score_combinations_new(
    method='tune_source',
    experiment_id='resnet50_aug_coarse_grad_ft',
)*100
tune_source_resnet50_cg.describe().T.sort_index()
# Out:
#       count       mean       std        min        25%        50%        75%  \
# A->D    5.0  74.235791  3.368923  70.764209  71.574501  73.594470  76.417051
# A->W    5.0  67.867579  1.512526  66.330444  66.806930  67.315614  68.996326
# D->A    5.0  51.597858  0.797264  50.850321  51.122555  51.386869  51.729391
# D->W    5.0  97.118793  0.282985  96.893241  96.893322  97.025054  97.215902
# W->A    5.0  52.986949  1.122007  51.810849  52.027985  52.815943  53.990733
# W->D    5.0  99.086022  1.051484  97.311828  99.193548  99.193548  99.731183
#
#              max
# A->D   78.828725
# A->W   69.888579
# D->A   52.900155
# D->W   97.566448
# W->A   54.289237
# W->D  100.000000

# %% [markdown]
# ### DAGE

# %%
# proper splits
dage_lda_resnet50_proper = get_score_combinations_new(
    method='dage',
    experiment_id='dage_lda_resnet50',
    config_dict={"test_as_val":0}
)*100
print(dage_lda_resnet50_proper.describe().T.sort_index()["mean"].mean())
dage_lda_resnet50_proper.describe().T.sort_index()
# Out:
# 86.80199586518926
#       count       mean       std        min        25%        50%        75%  \
# A->D    5.0  90.794163  0.932553  89.370200  90.418587  91.013825  91.501536
# A->W    5.0  90.860779  1.842254  88.864415  90.173053  90.650640  90.745088
# D->A    5.0  70.671931  0.909140  69.621887  70.104719  70.506549  71.198851
# D->W    5.0  98.930876  0.404172  98.433180  98.755760  98.924731  99.001536
# W->A    5.0  70.306915  1.654691  68.611291  68.931801  69.924724  71.835267
# W->D    5.0  99.247312  0.480875  98.655914  99.193548  99.193548  99.193548
#
#              max
# A->D   91.666667
# A->W   93.870699
# D->A   71.927649
# D->W   99.539171
# W->A   72.231493
# W->D  100.000000

# %%
# improper splits
dage_lda_resnet50_improper = get_score_combinations_new(
    method='dage',
    experiment_id='dage_lda_resnet50',
    config_dict={"test_as_val":1}
)*100
print(dage_lda_resnet50_improper.describe().T.sort_index()["mean"].mean())
dage_lda_resnet50_improper.describe().T.sort_index()
# Out:
# 87.20320463941533
#       count       mean       std        min        25%         50%  \
# A->D    5.0  90.550691  1.280100  89.189708  89.535330   90.253456
# A->W    5.0  91.587538  0.980703  90.487362  90.756806   91.660114
# D->A    5.0  71.114549  0.481602  70.555082  70.857737   71.100922
# D->W    5.0  99.050691  0.667576  98.141321  98.894009   99.001536
# W->A    5.0  71.238339  1.325544  69.791095  70.460477   70.732212
# W->D    5.0  99.677419  0.441712  99.193548  99.193548  100.000000
#
#              75%         max
# A->D   91.820276   91.954685
# A->W   92.189101   92.844306
# D->A   71.209934   71.849071
# D->W   99.216590  100.000000
# W->A   72.190007   73.017904
# W->D  100.000000  100.000000

# %%
# proper splits
dage_lda_vgg16_proper = get_score_combinations_new(
    method='dage',
    experiment_id='dage_lda_vgg16_tuned_v2',
    config_dict={"test_as_val":0}
)*100
print(dage_lda_vgg16_proper.describe().T.sort_index()["mean"].mean())
dage_lda_vgg16_proper.describe().T.sort_index()
# Out:
# 82.76847636170015
#       count       mean       std        min        25%        50%        75%  \
# A->D    5.0  85.375576  2.634884  81.954685  83.786482  85.933180  86.313364
# A->W    5.0  84.268688  1.716646  82.178010  83.041940  84.152281  85.950286
# D->A    5.0  64.876560  1.237723  63.286385  64.225389  65.005292  65.252054
# D->W    5.0  97.947493  0.339731  97.465438  97.849462  97.895545  98.170647
# W->A    5.0  65.454369  1.230775  63.416298  65.171601  66.086400  66.294265
# W->D    5.0  98.688172  0.515120  98.010753  98.387097  98.655914  99.193548
#
#             max
# A->D  88.890169
# A->W  86.020924
# D->A  66.613680
# D->W  98.356375
# W->A  66.303279
# W->D  99.193548

# %% [markdown]
# ### CCSA

# %%
# proper splits
ccsa_vgg16_proper = get_score_combinations_new(
    method='ccsa',
    experiment_id='ccsa_vgg16_tuned_v2',
    config_dict={"test_as_val":0}
)*100
print(ccsa_vgg16_proper.describe().T.sort_index()["mean"].mean())
ccsa_vgg16_proper.describe().T.sort_index()
# Out:
# 82.1722926729839
#       count       mean       std        min        25%        50%        75%  \
# A->D    5.0  86.355607  2.477475  82.442396  85.721966  86.824117  88.006912
# A->W    5.0  84.525464  2.061518  81.496962  83.910265  84.334671  86.267979
# D->A    5.0  65.533460  1.199817  63.586146  65.488821  65.568676  66.355994
# D->W    5.0  97.448122  0.864335  96.077363  97.434716  97.556207  97.709817
# W->A    5.0  60.753285  1.445514  58.754148  60.135008  60.955995  61.245537
# W->D    5.0  98.417819  0.918212  96.850998  98.463902  98.655914  98.924731
#
#             max
# A->D  88.782642
# A->W  86.617442
# D->A  66.667664
# D->W  98.462505
# W->A  62.675736
# W->D  99.193548

# %% [markdown]
# ### d-SNE

# %%
# proper splits
dsne_vgg16_proper = get_score_combinations_new(
    method='dsne',
    experiment_id='dsne_vgg16_tuned_v2',
    config_dict={"test_as_val":0}
)*100
print(dsne_vgg16_proper.describe().T.sort_index()["mean"].mean())
dsne_vgg16_proper.describe().T.sort_index()
# Out:
# 81.63139954170693
#       count       mean       std        min        25%         50%  \
# A->D    5.0  84.645929  1.306405  83.060676  83.782642   84.673579
# A->W    5.0  82.248576  2.367535  79.242934  80.472672   82.526542
# D->A    5.0  65.128929  0.916822  64.385530  64.473409   64.737855
# D->W    5.0  98.191733  0.432126  97.709817  97.895545   98.079877
# W->A    5.0  59.895811  1.640471  57.404667  59.669705   59.711829
# W->D    5.0  99.677419  0.441712  99.193548  99.193548  100.000000
#
#              75%         max
# A->D   85.291859   86.420891
# A->W   84.414349   84.586381
# D->A   65.464941   66.582909
# D->W   98.540707   98.732719
# W->A   60.982261   61.710592
# W->D  100.000000  100.000000

# %% [markdown]
# ### Summary

# %%
df_vgg16_tuned_proper = pd.concat([
    present(ccsa_vgg16_proper, 'CCSA'),
    present(dsne_vgg16_proper, 'd-SNE'),
    present(dage_lda_vgg16_proper, 'DAGE-LDA'),
])
df_vgg16_tuned_proper.style.apply(highlight_max)
# Out:
# <style  type="text/css" >
# #T_664cb_row0_col0,#T_664cb_row0_col1,#T_664cb_row0_col4,#T_664cb_row1_col3,#T_664cb_row1_col5,#T_664cb_row2_col2,#T_664cb_row2_col6{
#             font-weight:  bold;
#         }</style><table id="T_664cb_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A->W</th>        <th class="col_heading level0 col1" >A->D</th>        <th class="col_heading level0 col2" >W->A</th>        <th class="col_heading level0 col3" >W->D</th>        <th class="col_heading level0 col4" >D->A</th>        <th class="col_heading level0 col5" >D->W</th>        <th class="col_heading level0 col6" >mean</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_664cb_level0_row0" class="row_heading level0 row0" >CCSA</th>
#                         <td id="T_664cb_row0_col0" class="data row0 col0" >84.53 ±2.06</td>
#                         <td id="T_664cb_row0_col1" class="data row0 col1" >86.36 ±2.48</td>
#                         <td id="T_664cb_row0_col2" class="data row0 col2" >60.75 ±1.45</td>
#                         <td id="T_664cb_row0_col3" class="data row0 col3" >98.42 ±0.92</td>
#                         <td id="T_664cb_row0_col4" class="data row0 col4" >65.53 ±1.20</td>
#                         <td id="T_664cb_row0_col5" class="data row0 col5" >97.45 ±0.86</td>
#                         <td id="T_664cb_row0_col6" class="data row0 col6" >82.172293</td>
#             </tr>
#             <tr>
#                         <th id="T_664cb_level0_row1" class="row_heading level0 row1" >d-SNE</th>
#                         <td id="T_664cb_row1_col0" class="data row1 col0" >82.25 ±2.37</td>
#                         <td id="T_664cb_row1_col1" class="data row1 col1" >84.65 ±1.31</td>
#                         <td id="T_664cb_row1_col2" class="data row1 col2" >59.90 ±1.64</td>
#                         <td id="T_664cb_row1_col3" class="data row1 col3" >99.68 ±0.44</td>
#                         <td id="T_664cb_row1_col4" class="data row1 col4" >65.13 ±0.92</td>
#                         <td id="T_664cb_row1_col5" class="data row1 col5" >98.19 ±0.43</td>
#                         <td id="T_664cb_row1_col6" class="data row1 col6" >81.631400</td>
#             </tr>
#             <tr>
#                         <th id="T_664cb_level0_row2" class="row_heading level0 row2" >DAGE-LDA</th>
#                         <td id="T_664cb_row2_col0" class="data row2 col0" >84.27 ±1.72</td>
#                         <td id="T_664cb_row2_col1" class="data row2 col1" >85.38 ±2.63</td>
#                         <td id="T_664cb_row2_col2" class="data row2 col2" >65.45 ±1.23</td>
#                         <td id="T_664cb_row2_col3" class="data row2 col3" >98.69 ±0.52</td>
#                         <td id="T_664cb_row2_col4" class="data row2 col4" >64.88 ±1.24</td>
#                         <td id="T_664cb_row2_col5" class="data row2 col5" >97.95 ±0.34</td>
#                         <td id="T_664cb_row2_col6" class="data row2 col6" >82.768476</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # V4 - Additional Digits experiments

# %% [markdown]
# ## MNIST -> USPS

# %%
digits_mu = pd.concat([
    get_score_new(
        report_paths=load_cls_rep_paths_new(
            method=method, 
            experiment_id=f'{method}_digits_mnist_usps', 
        ),
        metric='recall',
        avg_types=['weighted avg'],
        map_col_name=lambda n: method
    )*100
    for method in ["ccsa", "dsne", "dage"]
], sort=False)
digits_mu.describe().T.style.apply(highlight_max)
# Out:
# <style  type="text/css" >
# #T_3369c_row0_col0,#T_3369c_row0_col2,#T_3369c_row1_col0,#T_3369c_row1_col1,#T_3369c_row1_col3,#T_3369c_row1_col4,#T_3369c_row1_col5,#T_3369c_row1_col6,#T_3369c_row1_col7,#T_3369c_row2_col0{
#             font-weight:  bold;
#         }</style><table id="T_3369c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >max</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3369c_level0_row0" class="row_heading level0 row0" >ccsa</th>
#                         <td id="T_3369c_row0_col0" class="data row0 col0" >5.000000</td>
#                         <td id="T_3369c_row0_col1" class="data row0 col1" >96.266630</td>
#                         <td id="T_3369c_row0_col2" class="data row0 col2" >0.482526</td>
#                         <td id="T_3369c_row0_col3" class="data row0 col3" >95.405294</td>
#                         <td id="T_3369c_row0_col4" class="data row0 col4" >96.447675</td>
#                         <td id="T_3369c_row0_col5" class="data row0 col5" >96.461391</td>
#                         <td id="T_3369c_row0_col6" class="data row0 col6" >96.488822</td>
#                         <td id="T_3369c_row0_col7" class="data row0 col7" >96.529968</td>
#             </tr>
#             <tr>
#                         <th id="T_3369c_level0_row1" class="row_heading level0 row1" >dsne</th>
#                         <td id="T_3369c_row1_col0" class="data row1 col0" >5.000000</td>
#                         <td id="T_3369c_row1_col1" class="data row1 col1" >96.554656</td>
#                         <td id="T_3369c_row1_col2" class="data row1 col2" >0.246384</td>
#                         <td id="T_3369c_row1_col3" class="data row1 col3" >96.118502</td>
#                         <td id="T_3369c_row1_col4" class="data row1 col4" >96.612262</td>
#                         <td id="T_3369c_row1_col5" class="data row1 col5" >96.653408</td>
#                         <td id="T_3369c_row1_col6" class="data row1 col6" >96.680839</td>
#                         <td id="T_3369c_row1_col7" class="data row1 col7" >96.708270</td>
#             </tr>
#             <tr>
#                         <th id="T_3369c_level0_row2" class="row_heading level0 row2" >dage</th>
#                         <td id="T_3369c_row2_col0" class="data row2 col0" >5.000000</td>
#                         <td id="T_3369c_row2_col1" class="data row2 col1" >96.269373</td>
#                         <td id="T_3369c_row2_col2" class="data row2 col2" >0.160829</td>
#                         <td id="T_3369c_row2_col3" class="data row2 col3" >96.008778</td>
#                         <td id="T_3369c_row2_col4" class="data row2 col4" >96.241942</td>
#                         <td id="T_3369c_row2_col5" class="data row2 col5" >96.296804</td>
#                         <td id="T_3369c_row2_col6" class="data row2 col6" >96.392813</td>
#                         <td id="T_3369c_row2_col7" class="data row2 col7" >96.406529</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## USPS -> MNIST

# %%
digits_um = pd.concat([
    get_score_new(
        report_paths=load_cls_rep_paths_new(
            method=method, 
            experiment_id=f'{method}_digits_usps_mnist', 
        ),
        metric='recall',
        avg_types=['weighted avg'],
        map_col_name=lambda n: method
    )*100
    for method in ["ccsa", "dsne", "dage"]
], sort=False)
digits_um.describe().T.style.apply(highlight_max)
# Out:
# <style  type="text/css" >
# #T_3f6d8_row0_col0,#T_3f6d8_row1_col0,#T_3f6d8_row1_col3,#T_3f6d8_row1_col5,#T_3f6d8_row1_col6,#T_3f6d8_row2_col0,#T_3f6d8_row2_col1,#T_3f6d8_row2_col2,#T_3f6d8_row2_col4,#T_3f6d8_row2_col7{
#             font-weight:  bold;
#         }</style><table id="T_3f6d8_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >max</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3f6d8_level0_row0" class="row_heading level0 row0" >ccsa</th>
#                         <td id="T_3f6d8_row0_col0" class="data row0 col0" >5.000000</td>
#                         <td id="T_3f6d8_row0_col1" class="data row0 col1" >93.206000</td>
#                         <td id="T_3f6d8_row0_col2" class="data row0 col2" >0.482162</td>
#                         <td id="T_3f6d8_row0_col3" class="data row0 col3" >92.490000</td>
#                         <td id="T_3f6d8_row0_col4" class="data row0 col4" >93.060000</td>
#                         <td id="T_3f6d8_row0_col5" class="data row0 col5" >93.280000</td>
#                         <td id="T_3f6d8_row0_col6" class="data row0 col6" >93.400000</td>
#                         <td id="T_3f6d8_row0_col7" class="data row0 col7" >93.800000</td>
#             </tr>
#             <tr>
#                         <th id="T_3f6d8_level0_row1" class="row_heading level0 row1" >dsne</th>
#                         <td id="T_3f6d8_row1_col0" class="data row1 col0" >5.000000</td>
#                         <td id="T_3f6d8_row1_col1" class="data row1 col1" >93.674000</td>
#                         <td id="T_3f6d8_row1_col2" class="data row1 col2" >0.453464</td>
#                         <td id="T_3f6d8_row1_col3" class="data row1 col3" >93.130000</td>
#                         <td id="T_3f6d8_row1_col4" class="data row1 col4" >93.240000</td>
#                         <td id="T_3f6d8_row1_col5" class="data row1 col5" >93.890000</td>
#                         <td id="T_3f6d8_row1_col6" class="data row1 col6" >94.030000</td>
#                         <td id="T_3f6d8_row1_col7" class="data row1 col7" >94.080000</td>
#             </tr>
#             <tr>
#                         <th id="T_3f6d8_level0_row2" class="row_heading level0 row2" >dage</th>
#                         <td id="T_3f6d8_row2_col0" class="data row2 col0" >5.000000</td>
#                         <td id="T_3f6d8_row2_col1" class="data row2 col1" >93.738000</td>
#                         <td id="T_3f6d8_row2_col2" class="data row2 col2" >0.646274</td>
#                         <td id="T_3f6d8_row2_col3" class="data row2 col3" >92.950000</td>
#                         <td id="T_3f6d8_row2_col4" class="data row2 col4" >93.370000</td>
#                         <td id="T_3f6d8_row2_col5" class="data row2 col5" >93.800000</td>
#                         <td id="T_3f6d8_row2_col6" class="data row2 col6" >93.890000</td>
#                         <td id="T_3f6d8_row2_col7" class="data row2 col7" >94.680000</td>
#             </tr>
#     </tbody></table>
